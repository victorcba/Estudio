# %% [markdown]
# <a href="https://colab.research.google.com/github/victorcba/Estudio/blob/victorcba-RamaEstudio/Filtro_pasa_Alto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar la imagen
image_path = 'imagen.jpg'
image = cv2.imread(image_path, 0)  # Leer la imagen en escala de grises

# Definir el kernel del filtro paso alto (filtro de realce de bordes)
kernel = np.array([[0, -1, 0],
                   [-1, 4, -1],
                   [0, -1, 0]], dtype=np.float32)

# Aplicar el filtro paso alto mediante convolución
filtered_image = cv2.filter2D(image, -1, kernel)

# Ajustar el rango de valores para visualización
filtered_image = np.clip(filtered_image, 0, 255).astype(np.uint8)

# Mostrar la imagen original y la imagen filtrada
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Imagen Original')
plt.subplot(1, 2, 2)
plt.imshow(filtered_image, cmap='gray')
plt.title('Imagen Filtrada (Paso Alto)')
plt.tight_layout()
plt.show()
