# %% [markdown]
# Matplotlib

# %%
import pandas as pd

# %%
tabla = pd.read_csv('C:/Users/cti9264/Documents/Vscode Python/ventasTotales.csv',skiprows=5,sep=';')

# %%
tabla.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 0  1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2  1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
#
#    Unidades Ganancia
# 0         6    18,00
# 1         8     3,84
# 2         3     6,30
# 3         9    14,40
# 4        14     6,72

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ali = tabla[tabla.Categoría == 'Comestibles']
ali.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# 5  1/1/2016  Trevor Snodgrass   Este            Cerveza  Comestibles
# 6  1/1/2016    Boris Stanford  Norte          Pepinillo  Comestibles
#
#    Unidades Ganancia
# 1         8     3,84
# 3         9    14,40
# 4        14     6,72
# 5        15     6,00
# 6        14     4,20

# %%
ali.Artículo.value_counts()
# Out:
# Pan                  26
# Chocolate            25
# Sánguche de Queso    25
# Pepinillo            24
# Soda                 19
# Cerveza              17
# Caramelos            17
# Name: Artículo, dtype: int64

# %%
ali.Artículo.value_counts().plot();

# %%
ali = tabla[tabla.Categoría == 'Comestibles']
ali.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# 5  1/1/2016  Trevor Snodgrass   Este            Cerveza  Comestibles
# 6  1/1/2016    Boris Stanford  Norte          Pepinillo  Comestibles
#
#    Unidades Ganancia
# 1         8     3,84
# 3         9    14,40
# 4        14     6,72
# 5        15     6,00
# 6        14     4,20

# %%
ali.Artículo.value_counts()
# Out:
# Pan                  26
# Chocolate            25
# Sánguche de Queso    25
# Pepinillo            24
# Soda                 19
# Cerveza              17
# Caramelos            17
# Name: Artículo, dtype: int64

# %%
ali.Artículo.value_counts().plot();

# %%
ali.Artículo.value_counts().plot(kind='bar',color='red');

# %%
ali.Artículo.value_counts().plot(kind='barh');

# %%
ali.Artículo.value_counts().plot(kind='pie',colormap='ocean');

# %%
tabla.plot(kind='scatter', x='Unidades', y='Ganancia');

# %%
ali.Artículo.value_counts().plot(kind='line',color='green',figsize=(10,5));
